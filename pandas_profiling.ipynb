# %%
import sys
sys.path
# Out:
# ['/Users/kamil/Desktop/SDA/Przetwarzenie_zbiorow_danych',
#  '/opt/anaconda3/envs/sda/lib/python310.zip',
#  '/opt/anaconda3/envs/sda/lib/python3.10',
#  '/opt/anaconda3/envs/sda/lib/python3.10/lib-dynload',
#  '',
#  '/opt/anaconda3/envs/sda/lib/python3.10/site-packages']

# %%
# !pip install pandas_profiling
# Out:
# Collecting pandas_profiling
#   Using cached pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Requirement already satisfied: jinja2>=2.11.1 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas_profiling) (3.1.2)
# Requirement already satisfied: PyYAML>=5.0.0 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas_profiling) (6.0)
# Requirement already satisfied: matplotlib>=3.2.0 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas_profiling) (3.5.2)
# Requirement already satisfied: scipy>=1.4.1 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas_profiling) (1.8.1)
# Collecting markupsafe~=2.1.1
#   Downloading MarkupSafe-2.1.1-cp310-cp310-macosx_10_9_x86_64.whl (13 kB)
# Collecting htmlmin>=0.1.12
#   Using cached htmlmin-0.1.12.tar.gz (19 kB)
# Collecting phik>=0.11.1
#   Downloading phik-0.12.2-cp310-cp310-macosx_10_13_x86_64.whl (812 kB)
#      |████████████████████████████████| 812 kB 1.9 MB/s eta 0:00:01
# Collecting requests>=2.24.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 7.9 MB/s  eta 0:00:01
# Collecting multimethod>=1.4
#   Using cached multimethod-1.8-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: numpy>=1.16.0 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas_profiling) (1.22.4)
# Collecting tangled-up-in-unicode==0.2.0
#   Using cached tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas_profiling) (1.4.2)
# Requirement already satisfied: seaborn>=0.10.1 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas_profiling) (0.11.2)
# Collecting visions[type_image_path]==0.7.4
#   Using cached visions-0.7.4-py3-none-any.whl (102 kB)
# Collecting missingno>=0.4.2
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: joblib~=1.1.0 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas_profiling) (1.1.0)
# Collecting tqdm>=4.48.2
#   Downloading tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 20.5 MB/s eta 0:00:01
# Collecting pydantic>=1.8.1
#   Downloading pydantic-1.9.2-cp310-cp310-macosx_10_9_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 53.4 MB/s eta 0:00:01
# Collecting networkx>=2.4
#   Downloading networkx-2.8.6-py3-none-any.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 27.1 MB/s eta 0:00:01
# Requirement already satisfied: attrs>=19.3.0 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (21.4.0)
# Collecting imagehash
#   Using cached ImageHash-4.2.1.tar.gz (812 kB)
# Requirement already satisfied: Pillow in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from visions[type_image_path]==0.7.4->pandas_profiling) (9.1.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from matplotlib>=3.2.0->pandas_profiling) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from matplotlib>=3.2.0->pandas_profiling) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from matplotlib>=3.2.0->pandas_profiling) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from matplotlib>=3.2.0->pandas_profiling) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from matplotlib>=3.2.0->pandas_profiling) (4.33.3)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from matplotlib>=3.2.0->pandas_profiling) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas_profiling) (2022.1)
# Collecting typing-extensions>=3.7.4.3
#   Downloading typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas_profiling) (1.16.0)
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.12-py2.py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 41.6 MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/sda/lib/python3.10/site-packages (from requests>=2.24.0->pandas_profiling) (2022.5.18.1)
# Collecting idna<4,>=2.5
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 11.9 MB/s eta 0:00:01
# Collecting PyWavelets
#   Downloading PyWavelets-1.3.0-cp310-cp310-macosx_10_13_x86_64.whl (4.4 MB)
#      |████████████████████████████████| 4.4 MB 33.7 MB/s eta 0:00:01
# Building wheels for collected packages: htmlmin, imagehash
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27096 sha256=df29a186acf12a9543bf1fff6d2fe43c83253af4f19a097d0f59d4c9c105d8d1
#   Stored in directory: /Users/kamil/Library/Caches/pip/wheels/dd/91/29/a79cecb328d01739e64017b6fb9a1ab9d8cb1853098ec5966d
#   Building wheel for imagehash (setup.py) ... done
#   Created wheel for imagehash: filename=ImageHash-4.2.1-py2.py3-none-any.whl size=295206 sha256=2019e7468a8124808de98ef42b62b5b67d6cb06e05cd8f09f72341f623d75b14
#   Stored in directory: /Users/kamil/Library/Caches/pip/wheels/37/84/30/6726df123f2fa8743637f767a88bb1300c33563f5b61a3fd56
# Successfully built htmlmin imagehash
# Installing collected packages: tangled-up-in-unicode, PyWavelets, networkx, multimethod, visions, urllib3, typing-extensions, markupsafe, imagehash, idna, charset-normalizer, tqdm, requests, pydantic, phik, missingno, htmlmin, pandas-profiling
#   Attempting uninstall: markupsafe
#     Found existing installation: MarkupSafe 2.0.1
#     Uninstalling MarkupSafe-2.0.1:
#       Successfully uninstalled MarkupSafe-2.0.1
# Successfully installed PyWavelets-1.3.0 charset-normalizer-2.1.1 htmlmin-0.1.12 idna-3.3 imagehash-4.2.1 markupsafe-2.1.1 missingno-0.5.1 multimethod-1.8 networkx-2.8.6 pandas-profiling-3.2.0 phik-0.12.2 pydantic-1.9.2 requests-2.28.1 tangled-up-in-unicode-0.2.0 tqdm-4.64.0 typing-extensions-4.3.0 urllib3-1.26.12 visions-0.7.4

# %%
# Standard Library Imports
from pathlib import Path

# Installed packages
import pandas as pd 
from ipywidgets import widgets

# Our package
from pandas_profiling import ProfileReport
from pandas_profiling.utils.cache import cache_file

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
# Generate the Profiling Report
profile = ProfileReport(
    df, title="Titanic Dataset", html={"style": {"full_width": True}}, sort="ascending"
)
# The Notebook Widgets Interface
profile.to_file("report_pandas_profiling.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
